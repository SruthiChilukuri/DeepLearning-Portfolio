# %% [markdown]
# <a href="https://colab.research.google.com/github/sruthi1996/DeepLearning/blob/master/animals_lesson2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *

# %%
folders = ['bengaltigers','lions','whitetigers']
path = Path('drive/My Drive/lesson2_datasets')

# %%
for folder in folders:
  dest = path/folder
  dest.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path.ls()
# Out:
# [PosixPath('drive/My Drive/lesson2_datasets/lions.txt'),
#  PosixPath('drive/My Drive/lesson2_datasets/bengaltigers.txt'),
#  PosixPath('drive/My Drive/lesson2_datasets/whitetigers.txt'),
#  PosixPath('drive/My Drive/lesson2_datasets/tigers'),
#  PosixPath('drive/My Drive/lesson2_datasets/lions'),
#  PosixPath('drive/My Drive/lesson2_datasets/whitetigers'),
#  PosixPath('drive/My Drive/lesson2_datasets/bengaltigers')]

# %%
files = ['bengaltigers.txt','lions.txt','whitetigers.txt']

# %%
for file, folder in zip(files, folders):
  download_images(path/file, path/folder, max_pics=150, max_workers=0)
# Out:
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# ...

# %%
for folder in folders:
  print(folder)
  verify_images(path/folder, delete=True, max_size=500)
# Out:
# bengaltigers
# lions
# whitetigers

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['bengaltigers', 'lions', 'whitetigers']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['bengaltigers', 'lions', 'whitetigers'], 3, 312, 78)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.724295</td>
#       <td>0.462821</td>
#       <td>0.166667</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.030672</td>
#       <td>0.323838</td>
#       <td>0.064103</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.763148</td>
#       <td>0.336514</td>
#       <td>0.064103</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.612279</td>
#       <td>0.318203</td>
#       <td>0.051282</td>
#       <td>01:39</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17' class='' max='25', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       68.00% [17/25 35:54<16:54]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.244031</td>
#       <td>0.307908</td>
#       <td>0.051282</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.257017</td>
#       <td>0.301524</td>
#       <td>0.051282</td>
#       <td>02:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
from fastai.widgets import *

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='7', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [7/7 01:26<00:00]
#     </div>
# Computing similarities...

# %%
learn.export()

# %%
img = open_image(path/'lions'/'00000017.jpg')
img
# Out:
# Image (3, 183, 275)

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category lions

# %% [markdown]
# #The model has hence detected the lion correctly.
